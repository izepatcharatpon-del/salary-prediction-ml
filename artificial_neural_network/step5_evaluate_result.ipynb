# %%
import pandas as pd
import joblib
import sklearn
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

# %%
data_test = pd.read_csv('./data/features.test.csv').set_index('id'); 
data_test
# Out:
#          fnlwgt  capitalgain  capitalloss  education  age-group  hoursperweek  \
# id
# 12849  3.062337     1.774050    -0.231477        9.0        1.0           2.0
# 1460   0.512789    -0.330368    -0.231477       13.0        0.0           3.0
# 13594 -0.434137    -0.330368    -0.231477       11.0        2.0           2.0
# 14333 -0.511783    -0.330368    -0.231477       11.0        2.0           3.0
# 10595 -1.012607    -0.330368    -0.231477        9.0        2.0           4.0
# ...         ...          ...          ...        ...        ...           ...
# 16929  0.004876    -0.330368    -0.231477       11.0        0.0           2.0
# 981    1.503056    -0.330368    -0.231477        7.0        1.0           3.0
# 2952  -1.297315    -0.330368    -0.231477        7.0        2.0           2.0
# 16559 -0.403644    -0.330368     6.058927       11.0        4.0           2.0
# 27733  1.692232    -0.330368    -0.231477       11.0        2.0           2.0
#
#        education-num  workclass_federal-gov  workclass_local-gov  \
# id
# 12849           12.0                    0.0                  0.0
# 1460             0.0                    0.0                  0.0
# 13594            8.0                    0.0                  0.0
# 14333            8.0                    0.0                  0.0
# 10595           12.0                    0.0                  0.0
# ...              ...                    ...                  ...
# 16929            8.0                    0.0                  0.0
# 981             11.0                    0.0                  0.0
# 2952            11.0                    0.0                  0.0
# 16559            8.0                    0.0                  1.0
# 27733            8.0                    0.0                  0.0
#
#        workclass_private  ...  native-country_puerto-rico  \
# id                        ...
# 12849                1.0  ...                         0.0
# 1460                 1.0  ...                         0.0
# 13594                1.0  ...                         0.0
# 14333                1.0  ...                         0.0
# 10595                1.0  ...                         0.0
# ...                  ...  ...                         ...
# 16929                1.0  ...                         0.0
# 981                  1.0  ...                         0.0
# 2952                 1.0  ...                         0.0
# 16559                0.0  ...                         0.0
# 27733                0.0  ...                         0.0
#
#        native-country_scotland  native-country_south  native-country_taiwan  \
# id
# 12849                      0.0                   0.0                    0.0
# 1460                       0.0                   0.0                    0.0
# 13594                      0.0                   0.0                    0.0
# 14333                      0.0                   0.0                    0.0
# 10595                      0.0                   0.0                    0.0
# ...                        ...                   ...                    ...
# 16929                      0.0                   0.0                    0.0
# 981                        0.0                   0.0                    0.0
# 2952                       0.0                   0.0                    0.0
# 16559                      0.0                   0.0                    0.0
# 27733                      0.0                   0.0                    0.0
#
#        native-country_thailand  native-country_trinadad&tobago  \
# id
# 12849                      0.0                             0.0
# 1460                       0.0                             0.0
# 13594                      0.0                             0.0
# 14333                      0.0                             0.0
# 10595                      0.0                             0.0
# ...                        ...                             ...
# 16929                      0.0                             0.0
# 981                        0.0                             0.0
# 2952                       0.0                             0.0
# 16559                      0.0                             0.0
# 27733                      0.0                             0.0
#
#        native-country_united-states  native-country_vietnam  \
# id
# 12849                           1.0                     0.0
# 1460                            0.0                     0.0
# 13594                           1.0                     0.0
# 14333                           1.0                     0.0
# 10595                           1.0                     0.0
# ...                             ...                     ...
# 16929                           1.0                     0.0
# 981                             1.0                     0.0
# 2952                            1.0                     0.0
# 16559                           1.0                     0.0
# 27733                           0.0                     0.0
#
#        native-country_yugoslavia  label
# id
# 12849                        0.0      1
# 1460                         0.0      0
# 13594                        0.0      0
# 14333                        0.0      1
# 10595                        0.0      0
# ...                          ...    ...
# 16929                        0.0      0
# 981                          0.0      0
# 2952                         0.0      1
# 16559                        0.0      0
# 27733                        0.0      0
#
# [4792 rows x 130 columns]

# %%
model = joblib.load('./model/model_ann.joblib') 
model
# Out:
# MLPClassifier(activation='tanh', alpha=0.0003, early_stopping=True,
#               learning_rate_init=0.0005, max_iter=800, n_iter_no_change=30,
#               random_state=1, verbose=True)

# %%
X_test = data_test.drop(columns='label')
y_test = data_test['label']

# %%
y_pred = model.predict(X_test)

# %%
data_test['prediction'] = y_pred
data_test.to_csv('./results/predictions.test.csv', index=False)

# %%
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Confusion Matrix:
# [[2249  476]
#  [ 436 1631]]

# %%
print("\nClassification Report:")
print(classification_report(y_test, y_pred, digits=3))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0      0.838     0.825     0.831      2725
#            1      0.774     0.789     0.782      2067
#
#     accuracy                          0.810      4792
#    macro avg      0.806     0.807     0.806      4792
# weighted avg      0.810     0.810     0.810      4792

# %%
scores = {
    'accuracy': accuracy_score(y_test, y_pred),
    'precision': precision_score(y_test, y_pred, average='weighted'),
    'recall': recall_score(y_test, y_pred, average='weighted'),
    'f1_score': f1_score(y_test, y_pred, average='weighted'),
    'support': len(y_test)
}

print("\nScores:", scores)
# Out:
# Scores: {'accuracy': 0.8096828046744574, 'precision': 0.8102131052470745, 'recall': 0.8096828046744574, 'f1_score': 0.8098911466536511, 'support': 4792}
